# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.optimizers import Adam

# %%
cancer_dataset = pd.read_csv('../Dataset/data.csv')

# %%
cancer_dataset = cancer_dataset.dropna(thresh=cancer_dataset.shape[1]-9, axis=0)

# %%
cancer_dataset.replace({'diagnosis': {'B':0, 'M':1}}, inplace=True)

# %%
cancer_dataset = cancer_dataset.drop(columns='id', axis=1)

# %%
cancer_dataset.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0          0.4601                  0.11890          NaN
# 1          0.2750                  0.08902          NaN
# 2          0.3613                  0.08758          NaN
# 3          0.6638                  0.17300          NaN
# 4          0.2364                  0.07678          NaN
#
# [5 rows x 32 columns]

# %%
cancer_dataset = cancer_dataset.drop(columns='Unnamed: 32', axis=1)

# %%
cancer_dataset.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
cancer_dataset.groupby('diagnosis').mean()
# Out:
#            radius_mean  texture_mean  perimeter_mean   area_mean  \
# diagnosis
# 0            12.146524     17.914762       78.075406  462.790196
# 1            17.462830     21.604906      115.365377  978.376415
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# 0                 0.092478          0.080085        0.046058
# 1                 0.102898          0.145188        0.160775
#
#            concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# diagnosis                                                              ...
# 0                     0.025717       0.174186                0.062867  ...
# 1                     0.087990       0.192909                0.062680  ...
#
#            radius_worst  texture_worst  perimeter_worst   area_worst  \
# diagnosis
# 0             13.379801      23.515070        87.005938   558.899440
# 1             21.134811      29.318208       141.370330  1422.286321
#
#            smoothness_worst  compactness_worst  concavity_worst  \
# diagnosis
# 0                  0.124959           0.182673         0.166238
# 1                  0.144845           0.374824         0.450606
#
#            concave points_worst  symmetry_worst  fractal_dimension_worst
# diagnosis
# 0                      0.074444        0.270246                 0.079442
# 1                      0.182237        0.323468                 0.091530
#
# [2 rows x 30 columns]

# %%
X = cancer_dataset.drop(columns='diagnosis', axis=1)
Y = cancer_dataset['diagnosis']

# %% [markdown]
# # Feature Selection Using one-way ANOVA

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
bestfeatures = SelectKBest(score_func=chi2, k=14)
fit = bestfeatures.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(16,'Score'))
# Out:
#                    Specs          Score
# 23            area_worst  112598.431564
# 3              area_mean   53991.655924
# 13               area_se    8758.504705
# 22       perimeter_worst    3665.035416
# 2         perimeter_mean    2011.102864
# 20          radius_worst     491.689157
# 0            radius_mean     266.104917
# 12          perimeter_se     250.571896
# 21         texture_worst     174.449400
# 1           texture_mean      93.897508
# 26       concavity_worst      39.516915
# 10             radius_se      34.675247
# 6         concavity_mean      19.712354
# 25     compactness_worst      19.314922
# 27  concave points_worst      13.485419
# 7    concave points_mean      10.544035

# %%
columns = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'concavity_mean', 'radius_se', 'perimeter_se', 'area_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'concave points_mean']

# %%
len(columns)
# Out:
# 16

# %%
X_new = pd.DataFrame(cancer_dataset, columns=columns)

# %%
X_new.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  concavity_mean  \
# 0        17.99         10.38          122.80     1001.0          0.3001
# 1        20.57         17.77          132.90     1326.0          0.0869
# 2        19.69         21.25          130.00     1203.0          0.1974
# 3        11.42         20.38           77.58      386.1          0.2414
# 4        20.29         14.34          135.10     1297.0          0.1980
#
#    radius_se  perimeter_se  area_se  radius_worst  texture_worst  \
# 0     1.0950         8.589   153.40         25.38          17.33
# 1     0.5435         3.398    74.08         24.99          23.41
# 2     0.7456         4.585    94.03         23.57          25.53
# 3     0.4956         3.445    27.23         14.91          26.50
# 4     0.7572         5.438    94.44         22.54          16.67
#
#    perimeter_worst  area_worst  compactness_worst  concavity_worst  \
# 0           184.60      2019.0             0.6656           0.7119
# 1           158.80      1956.0             0.1866           0.2416
# 2           152.50      1709.0             0.4245           0.4504
# 3            98.87       567.7             0.8663           0.6869
# 4           152.20      1575.0             0.2050           0.4000
#
#    concave points_worst  concave points_mean
# 0                0.2654              0.14710
# 1                0.1860              0.07017
# 2                0.2430              0.12790
# 3                0.2575              0.10520
# 4                0.1625              0.10430

# %%
x_train, x_test, y_train, y_test = train_test_split(X_new, Y, test_size = 0.2, random_state = 3, stratify=Y)

# %%
print(X.shape)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (569, 30)
# (455, 16)
# (114, 16)
# (455,)
# (114,)

# %% [markdown]
# # Normalizing

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train = x_train.reshape(455, 16, 1)
x_test = x_test.reshape(114, 16, 1)

# %% [markdown]
# # CNN

# %%
epochs = 100
model = Sequential()
model.add(Conv1D(filters=16, kernel_size=2, activation='relu', input_shape=(16,1)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

model.add(Conv1D(filters=16, kernel_size=2, activation='relu',))
model.add(Conv1D(filters=16, kernel_size=2, activation='relu',))
model.add(Conv1D(filters=16, kernel_size=2, activation='relu',))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))

# output layer
model.add(Dense(1, activation='sigmoid'))

# %%
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='best_model.{epoch:02d}-{val_loss:.2f}.h5',
        monitor='val_loss', save_best_only=True),
    keras.callbacks.EarlyStopping(monitor='acc', patience=1)
]
model.compile(loss='categorical_crossentropy',
                optimizer='adam', metrics=['accuracy'])

BATCH_SIZE = 400
EPOCHS = 50

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 15, 16)            48
#
#  conv1d_1 (Conv1D)           (None, 14, 16)            528
#
#  conv1d_2 (Conv1D)           (None, 13, 16)            528
#
#  conv1d_3 (Conv1D)           (None, 12, 16)            528
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 32)                6176
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,841
# Trainable params: 7,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, 
                    epochs=epochs, 
                    #callbacks=callbacks_list, 
                    validation_data = (x_test, y_test),
                    verbose=1)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 25ms/step - loss: 0.4063 - accuracy: 0.8879 - val_loss: 0.1375 - val_accuracy: 0.9561
# Epoch 2/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2065 - accuracy: 0.9451 - val_loss: 0.1184 - val_accuracy: 0.9649
# Epoch 3/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1497 - accuracy: 0.9560 - val_loss: 0.0816 - val_accuracy: 0.9561
# Epoch 4/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1298 - accuracy: 0.9516 - val_loss: 0.0903 - val_accuracy: 0.9649
# Epoch 5/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1261 - accuracy: 0.9516 - val_loss: 0.0785 - val_accuracy: 0.9649
# Epoch 6/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1234 - accuracy: 0.9604 - val_loss: 0.0778 - val_accuracy: 0.9649
# Epoch 7/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1187 - accuracy: 0.9604 - val_loss: 0.1166 - val_accuracy: 0.9386
# Epoch 8/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1151 - accuracy: 0.9538 - val_loss: 0.0768 - val_accuracy: 0.9561
# Epoch 9/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0920 - accuracy: 0.9692 - val_loss: 0.1582 - val_accuracy: 0.9298
# Epoch 10/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1185 - accuracy: 0.9473 - val_loss: 0.0760 - val_accuracy: 0.9737
# Epoch 11/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1133 - accuracy: 0.9648 - val_loss: 0.0886 - val_accuracy: 0.9474
# Epoch 12/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1117 - accuracy: 0.9626 - val_loss: 0.0880 - val_accuracy: 0.9649
# Epoch 13/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1170 - accuracy: 0.9626 - val_loss: 0.1072 - val_accuracy: 0.9386
# Epoch 14/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1032 - accuracy: 0.9626 - val_loss: 0.0723 - val_accuracy: 0.9825
# Epoch 15/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0977 - accuracy: 0.9560 - val_loss: 0.0949 - val_accuracy: 0.9561
# Epoch 16/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0959 - accuracy: 0.9604 - val_loss: 0.0710 - val_accuracy: 0.9737
# Epoch 17/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1014 - accuracy: 0.9626 - val_loss: 0.0708 - val_accuracy: 0.9649
# Epoch 18/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0868 - accuracy: 0.9692 - val_loss: 0.0673 - val_accuracy: 0.9737
# Epoch 19/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0988 - accuracy: 0.9736 - val_loss: 0.0741 - val_accuracy: 0.9649
# Epoch 20/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0938 - accuracy: 0.9714 - val_loss: 0.0916 - val_accuracy: 0.9649
# Epoch 21/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0866 - accuracy: 0.9670 - val_loss: 0.0605 - val_accuracy: 0.9737
# Epoch 22/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0857 - accuracy: 0.9670 - val_loss: 0.0738 - val_accuracy: 0.9737
# Epoch 23/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0805 - accuracy: 0.9670 - val_loss: 0.0642 - val_accuracy: 0.9737
# Epoch 24/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0727 - accuracy: 0.9780 - val_loss: 0.1029 - val_accuracy: 0.9474
# Epoch 25/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0676 - accuracy: 0.9736 - val_loss: 0.0777 - val_accuracy: 0.9649
# Epoch 26/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0652 - accuracy: 0.9692 - val_loss: 0.1134 - val_accuracy: 0.9386
# Epoch 27/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0684 - accuracy: 0.9758 - val_loss: 0.0695 - val_accuracy: 0.9649
# Epoch 28/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0662 - accuracy: 0.9736 - val_loss: 0.0608 - val_accuracy: 0.9737
# Epoch 29/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0695 - accuracy: 0.9736 - val_loss: 0.0619 - val_accuracy: 0.9825
# Epoch 30/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0612 - accuracy: 0.9692 - val_loss: 0.0635 - val_accuracy: 0.9825
# Epoch 31/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0694 - accuracy: 0.9802 - val_loss: 0.0646 - val_accuracy: 0.9737
# Epoch 32/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0915 - accuracy: 0.9604 - val_loss: 0.0735 - val_accuracy: 0.9649
# Epoch 33/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0575 - accuracy: 0.9758 - val_loss: 0.0469 - val_accuracy: 0.9825
# Epoch 34/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0880 - accuracy: 0.9736 - val_loss: 0.0724 - val_accuracy: 0.9649
# Epoch 35/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0606 - accuracy: 0.9714 - val_loss: 0.0864 - val_accuracy: 0.9737
# Epoch 36/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0598 - accuracy: 0.9780 - val_loss: 0.0500 - val_accuracy: 0.9649
# Epoch 37/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0871 - accuracy: 0.9802 - val_loss: 0.0609 - val_accuracy: 0.9737
# Epoch 38/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0651 - accuracy: 0.9714 - val_loss: 0.0535 - val_accuracy: 0.9912
# Epoch 39/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0877 - accuracy: 0.9692 - val_loss: 0.0961 - val_accuracy: 0.9649
# Epoch 40/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0626 - accuracy: 0.9824 - val_loss: 0.0653 - val_accuracy: 0.9737
# Epoch 41/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0753 - accuracy: 0.9736 - val_loss: 0.0563 - val_accuracy: 0.9649
# Epoch 42/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0691 - accuracy: 0.9780 - val_loss: 0.0876 - val_accuracy: 0.9737
# Epoch 43/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0665 - accuracy: 0.9780 - val_loss: 0.0697 - val_accuracy: 0.9649
# Epoch 44/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0458 - accuracy: 0.9780 - val_loss: 0.0568 - val_accuracy: 0.9737
# Epoch 45/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0741 - accuracy: 0.9802 - val_loss: 0.0859 - val_accuracy: 0.9561
# Epoch 46/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0377 - accuracy: 0.9912 - val_loss: 0.0495 - val_accuracy: 0.9737
# Epoch 47/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0376 - accuracy: 0.9802 - val_loss: 0.0522 - val_accuracy: 0.9737
# Epoch 48/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0341 - accuracy: 0.9846 - val_loss: 0.0708 - val_accuracy: 0.9737
# Epoch 49/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0378 - accuracy: 0.9824 - val_loss: 0.0506 - val_accuracy: 0.9737
# Epoch 50/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0335 - accuracy: 0.9824 - val_loss: 0.0318 - val_accuracy: 0.9825
# Epoch 51/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0653 - accuracy: 0.9758 - val_loss: 0.0755 - val_accuracy: 0.9737
# Epoch 52/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0613 - accuracy: 0.9824 - val_loss: 0.0690 - val_accuracy: 0.9649
# Epoch 53/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0361 - accuracy: 0.9890 - val_loss: 0.0618 - val_accuracy: 0.9737
# Epoch 54/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0322 - accuracy: 0.9846 - val_loss: 0.0713 - val_accuracy: 0.9825
# Epoch 55/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0426 - accuracy: 0.9824 - val_loss: 0.1976 - val_accuracy: 0.9386
# Epoch 56/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0535 - accuracy: 0.9714 - val_loss: 0.1093 - val_accuracy: 0.9561
# Epoch 57/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0583 - accuracy: 0.9802 - val_loss: 0.0742 - val_accuracy: 0.9737
# Epoch 58/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0423 - accuracy: 0.9802 - val_loss: 0.0740 - val_accuracy: 0.9649
# Epoch 59/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0349 - accuracy: 0.9802 - val_loss: 0.0813 - val_accuracy: 0.9737
# Epoch 60/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0216 - accuracy: 0.9912 - val_loss: 0.0909 - val_accuracy: 0.9649
# Epoch 61/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0199 - accuracy: 0.9912 - val_loss: 0.1006 - val_accuracy: 0.9474
# Epoch 62/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0326 - accuracy: 0.9868 - val_loss: 0.0962 - val_accuracy: 0.9474
# Epoch 63/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0211 - accuracy: 0.9890 - val_loss: 0.0341 - val_accuracy: 0.9912
# Epoch 64/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0392 - accuracy: 0.9912 - val_loss: 0.1193 - val_accuracy: 0.9649
# Epoch 65/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0983 - accuracy: 0.9780 - val_loss: 0.0827 - val_accuracy: 0.9561
# Epoch 66/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0534 - accuracy: 0.9802 - val_loss: 0.0765 - val_accuracy: 0.9649
# Epoch 67/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0688 - accuracy: 0.9758 - val_loss: 0.0712 - val_accuracy: 0.9737
# Epoch 68/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0614 - accuracy: 0.9802 - val_loss: 0.1030 - val_accuracy: 0.9649
# Epoch 69/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0469 - accuracy: 0.9780 - val_loss: 0.1052 - val_accuracy: 0.9649
# Epoch 70/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0367 - accuracy: 0.9824 - val_loss: 0.1521 - val_accuracy: 0.9649
# Epoch 71/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0257 - accuracy: 0.9912 - val_loss: 0.0612 - val_accuracy: 0.9737
# Epoch 72/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0281 - accuracy: 0.9846 - val_loss: 0.0580 - val_accuracy: 0.9737
# Epoch 73/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0274 - accuracy: 0.9846 - val_loss: 0.0727 - val_accuracy: 0.9737
# Epoch 74/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0231 - accuracy: 0.9890 - val_loss: 0.0531 - val_accuracy: 0.9825
# Epoch 75/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0277 - accuracy: 0.9868 - val_loss: 0.0596 - val_accuracy: 0.9825
# Epoch 76/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0175 - accuracy: 0.9890 - val_loss: 0.0490 - val_accuracy: 0.9825
# Epoch 77/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0137 - accuracy: 0.9934 - val_loss: 0.0613 - val_accuracy: 0.9737
# Epoch 78/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0115 - accuracy: 0.9934 - val_loss: 0.0553 - val_accuracy: 0.9737
# Epoch 79/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0154 - accuracy: 0.9934 - val_loss: 0.0701 - val_accuracy: 0.9649
# Epoch 80/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0107 - accuracy: 0.9934 - val_loss: 0.0797 - val_accuracy: 0.9649
# Epoch 81/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0103 - accuracy: 0.9956 - val_loss: 0.0549 - val_accuracy: 0.9825
# Epoch 82/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0232 - accuracy: 0.9934 - val_loss: 0.1461 - val_accuracy: 0.9561
# Epoch 83/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0178 - accuracy: 0.9934 - val_loss: 0.2997 - val_accuracy: 0.9298
# Epoch 84/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.2596 - accuracy: 0.9429 - val_loss: 0.0923 - val_accuracy: 0.9649
# Epoch 85/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1110 - accuracy: 0.9758 - val_loss: 0.0688 - val_accuracy: 0.9737
# Epoch 86/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0929 - accuracy: 0.9714 - val_loss: 0.0447 - val_accuracy: 0.9649
# Epoch 87/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0746 - accuracy: 0.9802 - val_loss: 0.0409 - val_accuracy: 0.9912
# Epoch 88/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0427 - accuracy: 0.9780 - val_loss: 0.1007 - val_accuracy: 0.9561
# Epoch 89/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0771 - accuracy: 0.9670 - val_loss: 0.0458 - val_accuracy: 0.9825
# Epoch 90/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0575 - accuracy: 0.9846 - val_loss: 0.0496 - val_accuracy: 0.9737
# Epoch 91/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0930 - accuracy: 0.9648 - val_loss: 0.0927 - val_accuracy: 0.9649
# Epoch 92/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0416 - accuracy: 0.9890 - val_loss: 0.0865 - val_accuracy: 0.9649
# Epoch 93/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0473 - accuracy: 0.9824 - val_loss: 0.0699 - val_accuracy: 0.9649
# Epoch 94/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0391 - accuracy: 0.9780 - val_loss: 0.0461 - val_accuracy: 0.9912
# Epoch 95/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0333 - accuracy: 0.9868 - val_loss: 0.0422 - val_accuracy: 0.9825
# Epoch 96/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0365 - accuracy: 0.9890 - val_loss: 0.0384 - val_accuracy: 0.9912
# Epoch 97/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0267 - accuracy: 0.9846 - val_loss: 0.0491 - val_accuracy: 0.9737
# Epoch 98/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0248 - accuracy: 0.9868 - val_loss: 0.0521 - val_accuracy: 0.9825
# Epoch 99/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0165 - accuracy: 0.9956 - val_loss: 0.0548 - val_accuracy: 0.9825
# Epoch 100/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0216 - accuracy: 0.9912 - val_loss: 0.0674 - val_accuracy: 0.9825

# %%
model.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 0.9825
# [0.06738894432783127, 0.9824561476707458]

# %%
# print(history.history.keys())
# # summarize history for accuracy
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()
# # summarize history for loss
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
X_new.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  concavity_mean  \
# 0        17.99         10.38          122.80     1001.0          0.3001
# 1        20.57         17.77          132.90     1326.0          0.0869
# 2        19.69         21.25          130.00     1203.0          0.1974
# 3        11.42         20.38           77.58      386.1          0.2414
# 4        20.29         14.34          135.10     1297.0          0.1980
#
#    radius_se  perimeter_se  area_se  radius_worst  texture_worst  \
# 0     1.0950         8.589   153.40         25.38          17.33
# 1     0.5435         3.398    74.08         24.99          23.41
# 2     0.7456         4.585    94.03         23.57          25.53
# 3     0.4956         3.445    27.23         14.91          26.50
# 4     0.7572         5.438    94.44         22.54          16.67
#
#    perimeter_worst  area_worst  compactness_worst  concavity_worst  \
# 0           184.60      2019.0             0.6656           0.7119
# 1           158.80      1956.0             0.1866           0.2416
# 2           152.50      1709.0             0.4245           0.4504
# 3            98.87       567.7             0.8663           0.6869
# 4           152.20      1575.0             0.2050           0.4000
#
#    concave points_worst  concave points_mean
# 0                0.2654              0.14710
# 1                0.1860              0.07017
# 2                0.2430              0.12790
# 3                0.2575              0.10520
# 4                0.1625              0.10430

# %%
input_data = (17.99, 10.38, 122.8, 1001, 0.3001, 1.0950, 8.589, 153.40, 153.40, 17.33, 184.60, 2019, 0.6656, 0.7119, 0.2, 0.2)

# %%
input_data_as_numpy_array = np.asarray(input_data)

# %%
input_data_reshape = input_data_as_numpy_array.reshape(1, -1)

# %%
std_data = scaler.transform(input_data_reshape)

# %%
prediction = model.predict(std_data)

# %%
if prediction[0]<=0.5:
    print("Benign")
else:
    print("Malignant")
# Out:
# Malignant

# %%
prediction
# Out:
# array([[1.]], dtype=float32)

# %%
model.save("model.h5")

# %% [markdown]
# # Saving the trained model

# %%
loaded_model = keras.models.load_model('model.h5')

# %%
input_data = (13.54, 14.36, 87.46, 566.3, 0.0664, 0.2699, 2.058, 23.56, 15.11, 19.26, 99.7, 711.2, 0.1773, 0.239, 0.05, 0.1)

input_data_as_numpy_array = np.asarray(input_data)

input_data_reshape = input_data_as_numpy_array.reshape(1, -1)

std_data = scaler.transform(input_data_reshape)

prediction = loaded_model.predict(std_data)

if prediction[0]<=0.5:
    print("Benign")
else:
    print("Malignant")
# Out:
# Benign

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
