# %% [markdown]
# ## Importing the Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
cancer_dataset = pd.read_csv('../Dataset/dataset_with_missing_values.csv')

# %%
cancer_dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00        NaN
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974                  NaN
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53              NaN      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245              NaN                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                      NaN
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
cancer_dataset = cancer_dataset.drop(columns='id', axis=1)

# %%
cancer_dataset.shape
# Out:
# (569, 31)

# %%
cancer_dataset.isnull().sum()
# Out:
# diagnosis                   0
# radius_mean                 0
# texture_mean                2
# perimeter_mean              0
# area_mean                   3
# smoothness_mean             7
# compactness_mean            3
# concavity_mean              5
# concave points_mean         6
# symmetry_mean               3
# fractal_dimension_mean      2
# radius_se                   4
# texture_se                  3
# perimeter_se                4
# area_se                     3
# smoothness_se              10
# compactness_se              6
# concavity_se                1
# concave points_se           6
# symmetry_se                 4
# fractal_dimension_se        2
# radius_worst                3
# texture_worst               1
# perimeter_worst             3
# area_worst                  4
# smoothness_worst            0
# compactness_worst           6
# concavity_worst             3
# concave points_worst        3
# symmetry_worst              1
# fractal_dimension_worst     3
# dtype: int64

# %%
cancer_dataset.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    567.000000      569.000000   566.000000
# mean     14.127292     19.280282       91.969033   653.184099
# std       3.524049      4.304076       24.298981   351.077970
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   419.925000
# 50%      13.370000     18.830000       86.240000   548.750000
# 75%      15.780000     21.790000      104.100000   782.200000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       562.000000        566.000000      564.000000           563.000000
# mean          0.096369          0.104322        0.088861             0.048879
# std           0.014047          0.052939        0.079945             0.038684
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086380          0.064605        0.029540             0.020365
# 50%           0.095930          0.092525        0.061400             0.033500
# 75%           0.105300          0.130400        0.131000             0.073820
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     566.000000              567.000000  ...    566.000000
# mean        0.181293                0.062769  ...     16.291129
# std         0.027402                0.007045  ...      4.833801
# min         0.106000                0.049960  ...      7.930000
# 25%         0.162000                0.057695  ...     13.035000
# 50%         0.179350                0.061490  ...     14.970000
# 75%         0.195700                0.066120  ...     18.805000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     568.000000       566.000000   565.000000        569.000000
# mean       25.666866       107.128110   876.649204          0.132369
# std         6.146704        33.504213   563.298946          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.075000        84.122500   514.000000          0.116600
# 50%        25.405000        97.655000   684.500000          0.131300
# 75%        29.675000       125.075000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         563.000000       566.000000            566.000000
# mean            0.255186         0.272630              0.114720
# std             0.157855         0.208644              0.065859
# min             0.027290         0.000000              0.000000
# 25%             0.146600         0.116475              0.064330
# 50%             0.215600         0.227450              0.100015
# 75%             0.340750         0.382400              0.162225
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      568.000000               566.000000
# mean         0.290246                 0.083936
# std          0.061789                 0.018106
# min          0.156500                 0.055040
# 25%          0.250475                 0.071318
# 50%          0.282250                 0.079960
# 75%          0.318025                 0.092088
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
cancer_dataset = cancer_dataset.dropna()

# %%
cancer_dataset.shape
# Out:
# (508, 31)

# %%
cancer_dataset.replace({'diagnosis': {'B':0, 'M':1}}, inplace=True)

# %%
cancer_dataset.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
# 5          1        12.45         15.70           82.57      477.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
# 5          0.12780           0.17000          0.1578              0.08089
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
# 5         0.2087  ...         15.47          23.75           103.40
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
# 5       741.6            0.1791             0.5249           0.5355
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
# 5                0.1741          0.3985                  0.12440
#
# [5 rows x 31 columns]

# %%
cancer_dataset['diagnosis'].value_counts()
# Out:
# 0    321
# 1    187
# Name: diagnosis, dtype: int64

# %%
cancer_dataset.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
cancer_dataset.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  508.000000   508.000000    508.000000      508.000000   508.000000
# mean     0.368110    14.159831     19.258327       92.189902   658.252559
# std      0.482767     3.552261      4.335279       24.515860   357.139876
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.677500     16.060000       74.967500   418.325000
# 50%      0.000000    13.280000     18.835000       85.865000   545.650000
# 75%      1.000000    16.080000     21.802500      105.725000   799.100000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       508.000000        508.000000      508.000000           508.000000
# mean          0.096302          0.104365        0.089308             0.049156
# std           0.014189          0.052684        0.080220             0.039381
# min           0.062510          0.019380        0.000000             0.000000
# 25%           0.085992          0.063755        0.029720             0.020347
# 50%           0.095725          0.092455        0.060705             0.033300
# 75%           0.105400          0.130700        0.131000             0.074842
# max           0.163400          0.311400        0.426800             0.201200
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count     508.000000  ...    508.000000     508.000000       508.000000
# mean        0.181337  ...     16.305980      25.628051       107.523583
# std         0.026907  ...      4.868981       6.225957        33.915142
# min         0.106000  ...      7.930000      12.020000        50.410000
# 25%         0.163200  ...     13.002500      20.910000        84.102500
# 50%         0.179900  ...     14.905000      25.305000        97.140000
# 75%         0.195400  ...     19.097500      29.547500       126.750000
# max         0.304000  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count   508.000000        508.000000         508.000000       508.000000
# mean    884.627165          0.132104           0.254853         0.273025
# std     573.487366          0.023077           0.158429         0.207278
# min     185.200000          0.071170           0.027290         0.000000
# 25%     513.775000          0.115175           0.145325         0.114475
# 50%     676.250000          0.131200           0.212950         0.229000
# 75%    1106.750000          0.146000           0.340325         0.383500
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count            508.000000      508.000000               508.000000
# mean               0.114591        0.289655                 0.083780
# std                0.065894        0.060043                 0.017903
# min                0.000000        0.156500                 0.055040
# 25%                0.063737        0.250475                 0.071270
# 50%                0.098840        0.282450                 0.079590
# 75%                0.162575        0.318475                 0.092082
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 31 columns]

# %%
cancer_dataset.groupby('diagnosis').mean()
# Out:
#            radius_mean  texture_mean  perimeter_mean   area_mean  \
# diagnosis
# 0            12.154997     17.769439       78.111495  463.004361
# 1            17.601283     21.814118      116.356578  993.411230
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# 0                 0.092362          0.079508        0.045695
# 1                 0.103067          0.147034        0.164172
#
#            concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# diagnosis                                                              ...
# 0                     0.025491       0.174789                0.062739  ...
# 1                     0.089780       0.192578                0.062689  ...
#
#            radius_worst  texture_worst  perimeter_worst   area_worst  \
# diagnosis
# 0             13.387377      23.324673        87.036262   559.207477
# 1             21.315989      29.581979       142.691658  1443.235294
#
#            smoothness_worst  compactness_worst  concavity_worst  \
# diagnosis
# 0                  0.124573           0.181944         0.166901
# 1                  0.145031           0.380008         0.455196
#
#            concave points_worst  symmetry_worst  fractal_dimension_worst
# diagnosis
# 0                      0.074376        0.271393                 0.079214
# 1                      0.183623        0.321003                 0.091618
#
# [2 rows x 30 columns]

# %%
x = cancer_dataset.drop(columns='diagnosis', axis=1)
y = cancer_dataset['diagnosis']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y)

# %%
print(x.shape)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (508, 30)
# (406, 30)
# (102, 30)
# (406,)
# (102,)

# %%
scaler = StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train = scaler.transform(x_train)

x_test = scaler.transform(x_test)

# %%
model = svm.SVC(kernel='linear')

# %%
#training the SVM model with training data
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# accuracy score on training data
x_train_prediction = model.predict(x_train)

training_data_accuracy = accuracy_score(y_train, x_train_prediction)

# %%
print('Accuracy score of Training data: ', training_data_accuracy)
# Out:
# Accuracy score of Training data:  0.9926108374384236

# %%
# accuracy score on test data
x_test_prediction = model.predict(x_test)

test_data_accuracy = accuracy_score(y_test, x_test_prediction)

# %%
print('Accuracy score of test data: ', test_data_accuracy)
# Out:
# Accuracy score of test data:  0.9705882352941176
